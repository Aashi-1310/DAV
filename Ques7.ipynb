# %%
import pandas as pd
import numpy as np

# %%
data={
    'Name' : ['Mudit Chauhan','Seema Chopra','Rani Gupta','Aditya Narayan','Sanjeev Sahni','Prakash Kumar','Ritu Aggarwal','Akshay Goel','Meeta Kulkarni','Preeti Ahuja','Sunil Das Gupta','Sonali Sapre','Rashmi Talwar','Ashish Dubey','Kiran Sharma','Sameer Bansal'],
    'Birth_Month' : ['Dec','Jan','Mar','Oct','Feb','Dec','Sep','Aug','Jul','Nov','Apr','Jan','Jun','May','Feb','Oct'],
    'Gender' : ['M','F','F','M','M','M','F','M','F','F','M','F','F','M','F','M'],
    'Pass_Division' : ['III','II','I','I','II','III','I','I','II','II','III','I','III','II','II','I']   
}
df=pd.DataFrame(data)
df
# Out:
#                Name Birth_Month Gender Pass_Division
# 0     Mudit Chauhan         Dec      M           III
# 1      Seema Chopra         Jan      F            II
# 2        Rani Gupta         Mar      F             I
# 3    Aditya Narayan         Oct      M             I
# 4     Sanjeev Sahni         Feb      M            II
# 5     Prakash Kumar         Dec      M           III
# 6     Ritu Aggarwal         Sep      F             I
# 7       Akshay Goel         Aug      M             I
# 8    Meeta Kulkarni         Jul      F            II
# 9      Preeti Ahuja         Nov      F            II
# 10  Sunil Das Gupta         Apr      M           III
# 11     Sonali Sapre         Jan      F             I
# 12    Rashmi Talwar         Jun      F           III
# 13     Ashish Dubey         May      M            II
# 14     Kiran Sharma         Feb      F            II
# 15    Sameer Bansal         Oct      M             I

# %%
df=pd.get_dummies(df,columns=['Gender','Pass_Division'])
df
# Out:
#                Name Birth_Month  Gender_F  Gender_M  Pass_Division_I  \
# 0     Mudit Chauhan         Dec     False      True            False
# 1      Seema Chopra         Jan      True     False            False
# 2        Rani Gupta         Mar      True     False             True
# 3    Aditya Narayan         Oct     False      True             True
# 4     Sanjeev Sahni         Feb     False      True            False
# 5     Prakash Kumar         Dec     False      True            False
# 6     Ritu Aggarwal         Sep      True     False             True
# 7       Akshay Goel         Aug     False      True             True
# 8    Meeta Kulkarni         Jul      True     False            False
# 9      Preeti Ahuja         Nov      True     False            False
# 10  Sunil Das Gupta         Apr     False      True            False
# 11     Sonali Sapre         Jan      True     False             True
# 12    Rashmi Talwar         Jun      True     False            False
# 13     Ashish Dubey         May     False      True            False
# 14     Kiran Sharma         Feb      True     False            False
# 15    Sameer Bansal         Oct     False      True             True
#
#     Pass_Division_II  Pass_Division_III
# 0              False               True
# 1               True              False
# 2              False              False
# 3              False              False
# 4               True              False
# 5              False               True
# 6              False              False
# 7              False              False
# 8               True              False
# 9               True              False
# 10             False               True
# 11             False              False
# 12             False               True
# 13              True              False
# 14              True              False
# 15             False              False

# %%
df["Birth_Month"]=df.Birth_Month.astype("category")
df
# Out:
#                Name Birth_Month  Gender_F  Gender_M  Pass_Division_I  \
# 0     Mudit Chauhan         Dec     False      True            False
# 1      Seema Chopra         Jan      True     False            False
# 2        Rani Gupta         Mar      True     False             True
# 3    Aditya Narayan         Oct     False      True             True
# 4     Sanjeev Sahni         Feb     False      True            False
# 5     Prakash Kumar         Dec     False      True            False
# 6     Ritu Aggarwal         Sep      True     False             True
# 7       Akshay Goel         Aug     False      True             True
# 8    Meeta Kulkarni         Jul      True     False            False
# 9      Preeti Ahuja         Nov      True     False            False
# 10  Sunil Das Gupta         Apr     False      True            False
# 11     Sonali Sapre         Jan      True     False             True
# 12    Rashmi Talwar         Jun      True     False            False
# 13     Ashish Dubey         May     False      True            False
# 14     Kiran Sharma         Feb      True     False            False
# 15    Sameer Bansal         Oct     False      True             True
#
#     Pass_Division_II  Pass_Division_III
# 0              False               True
# 1               True              False
# 2              False              False
# 3              False              False
# 4               True              False
# 5              False               True
# 6              False              False
# 7              False              False
# 8               True              False
# 9               True              False
# 10             False               True
# 11             False              False
# 12             False               True
# 13              True              False
# 14              True              False
# 15             False              False

# %%
df.dtypes
# Out:
# Name                   object
# Birth_Month          category
# Gender_F                 bool
# Gender_M                 bool
# Pass_Division_I          bool
# Pass_Division_II         bool
# Pass_Division_III        bool
# dtype: object

# %%
month=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
df['Birth_Month']=pd.Categorical(df['Birth_Month'] , categories = month)     #used for passing the list for sort values
df.sort_values(by='Birth_Month' ,inplace=True)
df
# Out:
#                Name Birth_Month  Gender_F  Gender_M  Pass_Division_I  \
# 1      Seema Chopra         Jan      True     False            False
# 11     Sonali Sapre         Jan      True     False             True
# 4     Sanjeev Sahni         Feb     False      True            False
# 14     Kiran Sharma         Feb      True     False            False
# 2        Rani Gupta         Mar      True     False             True
# 10  Sunil Das Gupta         Apr     False      True            False
# 13     Ashish Dubey         May     False      True            False
# 12    Rashmi Talwar         Jun      True     False            False
# 8    Meeta Kulkarni         Jul      True     False            False
# 7       Akshay Goel         Aug     False      True             True
# 6     Ritu Aggarwal         Sep      True     False             True
# 3    Aditya Narayan         Oct     False      True             True
# 15    Sameer Bansal         Oct     False      True             True
# 9      Preeti Ahuja         Nov      True     False            False
# 0     Mudit Chauhan         Dec     False      True            False
# 5     Prakash Kumar         Dec     False      True            False
#
#     Pass_Division_II  Pass_Division_III
# 1               True              False
# 11             False              False
# 4               True              False
# 14              True              False
# 2              False              False
# 10             False               True
# 13              True              False
# 12             False               True
# 8               True              False
# 7              False              False
# 6              False              False
# 3              False              False
# 15             False              False
# 9               True              False
# 0              False               True
# 5              False               True
