# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\hp\Downloads\weather.csv")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df2 = df.groupby('Data.Wind.Direction')['Data.Wind.Speed'].mean().reset_index()
df2
# Out:
#     Data.Wind.Direction  Data.Wind.Speed
# 0                     0         0.000000
# 1                     1         7.541905
# 2                     2         7.576667
# 3                     3         8.118889
# 4                     4         9.440952
# 5                     5         9.271781
# 6                     6         7.325926
# 7                     7         7.119702
# 8                     8         6.665482
# 9                     9         6.525742
# 10                   10         6.333322
# 11                   11         6.523163
# 12                   12         6.213000
# 13                   13         6.021891
# 14                   14         5.937515
# 15                   15         6.144901
# 16                   16         6.004297
# 17                   17         6.139061
# 18                   18         5.834601
# 19                   19         6.051960
# 20                   20         6.054480
# 21                   21         6.226905
# ...

# %%
from datetime import datetime
df['Date.Full'] = pd.to_datetime(df['Date.Full'])
df
# Out:
#        Data.Precipitation  Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00 2016-01-03           1             3       2016
# 1                    0.00 2016-01-03           1             3       2016
# 2                    0.16 2016-01-03           1             3       2016
# 3                    0.00 2016-01-03           1             3       2016
# 4                    0.01 2016-01-03           1             3       2016
# ...                   ...        ...         ...           ...        ...
# 16738                0.08 2017-01-01           1             1       2017
# 16739                0.00 2017-01-01           1             1       2017
# 16740                0.00 2017-01-01           1             1       2017
# 16741                0.06 2017-01-01           1             1       2017
# 16742                0.10 2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
df['Date.Full'].dtype
# Out:
# dtype('<M8[ns]')

# %%
pd.qcut(df['Data.Temperature.Avg Temp'], 5).value_counts()
# Out:
# Data.Temperature.Avg Temp
# (-27.001, 40.0]    3482
# (53.0, 63.0]       3457
# (40.0, 53.0]       3395
# (63.0, 74.0]       3335
# (74.0, 100.0]      3074
# Name: count, dtype: int64
